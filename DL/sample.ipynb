# %%
# Out:
# Running cells with 'env (3.14.0) (Python 3.14.0)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/Users/hp/ProjectAndCode/DataScience/env/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
# Out:
# Running cells with 'env (3.14.0) (Python 3.14.0)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/Users/hp/ProjectAndCode/DataScience/env/bin/python -m pip install ipykernel -U --force-reinstall'
