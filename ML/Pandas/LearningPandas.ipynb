# %%
import pandas as pd
import numpy as np
data = {
    "names" : ["raj","rajesh","mukesh"],
    "age" : [24,22,21]
}

# %%
df = pd.read_csv("data.csv")

# %% [markdown]
# # Explore the Data
# * 1. head rows
# * 2. Tail rows
# * 3. shape
# * 4. columns
# * 5. index
# * 6. datatypes

# %%
df.head(2)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650

# %%
df.tail(2)
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
#                   Market Category Vehicle Size  Vehicle Style  highway MPG  \
# 11912  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback           23
# 11913                      Luxury      Midsize          Sedan           26
#
#        city mpg  Popularity   MSRP
# 11912        16         204  50920
# 11913        17          61  28995

# %%
df.shape    # to check the total count of rows and column
# Out:
# (11914, 16)

# %%
df.columns    #. to list all the column name
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
df.index       # to check the index
# Out:
# RangeIndex(start=0, stop=11914, step=1)

# %%
df.dtypes        # to list all the column with datatypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
df["Year"] = df["Year"].astype("int8")   # to transfor the datat-type

# %%
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                    int8
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
df.size
# Out:
# 190624

# %%
# df = pd.read_csv("/Users/hp/ProjectAndCode/DataScience/Electric_Vehicle_Population_Data(1).csv",sep=",")

# %%
df.head(2)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M   -37  premium unleaded (required)      335.0
# 1  BMW    1 Series   -37  premium unleaded (required)      300.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650

# %%
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                    int8
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
df.shape
# Out:
# (11914, 16)

# %%
df.to_excel(excel_writer="output.xlsx",sheet_name="mydata")

# %%
df.to_csv("output.csv")

# %%
df = pd.read_csv("data.csv")

# %%
ar = np.arange(100)
ar==1
# Out:
# array([False,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False])

# %%
df["superCars"] = df["Engine HP"]>500   # to create new column

# %%
df[df["Engine HP"]>500][["Engine HP","Year"]].head(3)
# Out:
#      Engine HP  Year
# 466      562.0  2013
# 467      562.0  2013
# 468      562.0  2014

# %%
d = {
    "one":1,
    "two":2
}
d["two"] = 3
print(d)
# Out:
# {'one': 1, 'two': 3}

# %%
df.insert(5,"superEngine",df["Engine Cylinders"]>=8)

# %%
df[df["Engine Cylinders"]>=8].head(2)
# Out:
#         Make Model  Year             Engine Fuel Type  Engine HP  superEngine  \
# 294  Ferrari   360  2002  premium unleaded (required)      400.0         True
# 295  Ferrari   360  2002  premium unleaded (required)      400.0         True
#
#      Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 294               8.0            MANUAL  rear wheel drive              2.0
# 295               8.0            MANUAL  rear wheel drive              2.0
#
#              Market Category Vehicle Size Vehicle Style  highway MPG  \
# 294  Exotic,High-Performance      Compact   Convertible           15
# 295  Exotic,High-Performance      Compact         Coupe           15
#
#      city mpg  Popularity    MSRP  superCars
# 294        10        2774  160829      False
# 295        10        2774  140615      False

# %% [markdown]
# # axis =0 row.   default value
# # axis =1 column
# # inplace need to set true if we want to modify the current object

# %%
df.drop(["superCars"],axis=1,inplace=True) # to drop multiple column put[]

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP', 'superEngine',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %% [markdown]
# #### till this point we did
# * #### Data Load
# * #### data features (explore)
# * #### add column
# * #### add filtered data as new column
# * #### add column with insert method

# %% [markdown]
#  ####  the next
#  * #### how to update the name of the column
# * ####  how to filter records(row)
# * ####  how to remove the unwanted records(rows)
# * ####  what is role of index
# * ####  how to reset the sequence of rows(index)

# %%
columns = list(df.columns)
columns[1] = "CarModel"
df.columns = columns
df.head(1)
# Out:
#   Make    CarModel  Year             Engine Fuel Type  Engine HP  superEngine  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0        False
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135

# %%
df.rename(columns={"Make":"CarBrand"},inplace=True)
df.head(1)
# Out:
#   CarBrand    CarModel  Year             Engine Fuel Type  Engine HP  \
# 0      BMW  1 Series M  2011  premium unleaded (required)      335.0
#
#    superEngine  Engine Cylinders Transmission Type     Driven_Wheels  \
# 0        False               6.0            MANUAL  rear wheel drive
#
#    Number of Doors                        Market Category Vehicle Size  \
# 0              2.0  Factory Tuner,Luxury,High-Performance      Compact
#
#   Vehicle Style  highway MPG  city mpg  Popularity   MSRP
# 0         Coupe           26        19        3916  46135

# %%
dfnew = df.copy()

# %%
id(df) == id(dfnew)
# Out:
# False

# %%
df['Engine HP']
# Out:
# 0        335.0
# 1        300.0
# 2        300.0
# 3        230.0
# 4        230.0
#          ...
# 11909    300.0
# 11910    300.0
# 11911    300.0
# 11912    300.0
# 11913    221.0
# Name: Engine HP, Length: 11914, dtype: float64

# %%
# Product.objects.all()   # select `id`,`name`,`price`,`quantity` from `product`;

# %%
df[(df["CarBrand"]=="BMW") & (df["Engine HP"]>500) ].head(1)

# %%
df.query(""" `CarBrand`=="BMW" and `Engine HP`>500 """).head(1)
# Out:
#     CarBrand  CarModel  Year             Engine Fuel Type  Engine HP  \
# 720      BMW  7 Series  2015  premium unleaded (required)      535.0
#
#      superEngine  Engine Cylinders Transmission Type     Driven_Wheels  \
# 720         True              12.0         AUTOMATIC  rear wheel drive
#
#      Number of Doors          Market Category Vehicle Size Vehicle Style  \
# 720              4.0  Luxury,High-Performance        Large         Sedan
#
#      highway MPG  city mpg  Popularity    MSRP
# 720           20        13        3916  141200

# %% [markdown]
# * group by
#
#
# * and aggrigate function
#
# * count
# * sum
# * mean
# * max
# * min

# %%
df.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %%
pd.set_option('display.max_rows',None)

# %%
df.groupby(by=["CarBrand","Year"])[["MSRP","Engine Cylinders"]].sum()
# Out:
#                        MSRP  Engine Cylinders
# CarBrand      Year
# Acura         1992     4000              10.0
#               1993    14102              40.0
#               1994    14722              40.0
#               1995    13472              36.0
#               1997     4885              12.0
#               1998     2816               6.0
#               1999    21208              30.0
#               2000    27122              28.0
#               2001   295010              56.0
#               2002    58060              12.0
#               2003   152350              30.0
#               2004   285370              32.0
#               2005   286720              32.0
#               2006   109245              20.0
#               2010   201980              24.0
#               2011   358160              42.0
#               2012   915355             120.0
#               2013   610570              84.0
#               2014   625025              86.0
# ...

# %%
df.groupby(by="CarBrand")[["MSRP","Engine Cylinders"]].aggregate(["sum","mean","max"])
# Out:
#                    MSRP                        Engine Cylinders             \
#                     sum          mean      max              sum       mean
# CarBrand
# Acura           8791672  3.488759e+04   156000           1344.0   5.333333
# Alfa Romeo       308000  6.160000e+04    68400             20.0   4.000000
# Aston Martin   18405665  1.979104e+05   320695            988.0  10.623656
# Audi           17532293  5.345211e+04   199900           1823.0   5.557927
# BMW            20556619  6.154676e+04   141200           1990.0   5.958084
# Bentley        18290530  2.471693e+05   363000            720.0   9.729730
# Bugatti         5271671  1.757224e+06  2065902             48.0  16.000000
# Buick           5528496  2.820661e+04    49625           1042.0   5.316327
# Cadillac       22323833  5.623132e+04   104215           2554.0   6.433249
# Chevrolet      31837483  2.835039e+04    92395           6623.0   5.908118
# ...
