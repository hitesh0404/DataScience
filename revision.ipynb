# %%
# lambda function 
a = lambda x : (x**2,x**3)
a(2)
a(5)
# Out:
# (25, 125)

# %%
def double(x):
    return x**2

# %%
print(
        list(
                map(
                    lambda x: x**2 ,
                    [1,2,3,4,5]
                    )
                )
    )

print(
    list(
        map(
            lambda x: [i**2 for i in x] , 
            [[1,2,3],[3,4,5]] 
            )
        ) 
    )
# Out:
# [1, 4, 9, 16, 25]
# [[1, 4, 9], [9, 16, 25]]

# %%
from functools import reduce
list(filter(lambda x: int(x)%2 == 0 if x != "0" else False ,"0123456789"))

reduce(lambda x,y : x*y ,(1,2,3,4))
# Out:
# 24

# %%
x = [1,2,3]
w = [0.2,0.4,0.6]
print(list(zip(x,w)))
reduce(lambda x,y:x*y,[[3,2],[3,4],3,])
# Out:
# [(1, 0.2), (2, 0.4), (3, 0.6)]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 4
#       2 w = [0.2,0.4,0.6]
#       3 print(list(zip(x,w)))
# ----> 4 reduce(lambda x,y:x*y,[[3,2],[3,4],3,])
#
# Cell In[57], line 4, in <lambda>(x, y)
#       2 w = [0.2,0.4,0.6]
#       3 print(list(zip(x,w)))
# ----> 4 reduce(lambda x,y:x*y,[[3,2],[3,4],3,])
#
# TypeError: can't multiply sequence by non-int of type 'list'

# %%
[3, 2, 3, 2, 3, 2] *3
# Out:
# [3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2, 3, 2]

# %%
dict(
    map(
        lambda x: 
            (x[0]**2,x[1]**2) if x[0]==x[0] else (x[0],x[0]),
    
            {1:2,2:2,}.items()
        )
    )
# Out:
# {1: 4, 4: 4}

# %% [markdown]
# # Null values
# ###  Mean Median Mode
# # dupliates
# # outlier  IQR Q1 Q2 Q3
# - lower = Q1-1.5*IQR
# - ipper = Q3+1.5*IQR
# # Z score
# - (x - mean(x)/sd)  -3 to 3
# # skew
# <img src ="skewness.svg" style="background-color:white;">
#
# ### log1p
# ### sqrt
# ### zscore
# # Encoding
# # scaling
# # Feature engineering
